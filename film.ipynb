# %%
import pandas as pd

df = pd.read_csv('moviesTMBD.csv')

df
# Out:
#       Unnamed: 0       id                     title  popularity  adult  \
# 0              0  1007757                   Swapped    327.5134  False
# 1              1      278  The Shawshank Redemption     65.3308  False
# 2              2      238             The Godfather     47.2346  False
# 3              3   687163         Project Hail Mary    422.0199  False
# 4              4      240     The Godfather Part II     27.6763  False
# ...          ...      ...                       ...         ...    ...
# 9975        9975   399173            The Assignment      2.1132  False
# 9976        9976   613377               30 Days Max      1.2237  False
# 9977        9977     8859     Dude, Where's My Car?      2.8157  False
# 9978        9978   313943                    Revolt      1.4022  False
# 9979        9979   277355                    Everly      2.0746  False
#
#      original_language                                           overview  \
# ...

# %%
df[df['vote_count'] > 1000]
# Out:
#       Unnamed: 0       id                              title  popularity  \
# 0              0  1007757                            Swapped    327.5134
# 1              1      278           The Shawshank Redemption     65.3308
# 2              2      238                      The Godfather     47.2346
# 3              3   687163                  Project Hail Mary    422.0199
# 4              4      240              The Godfather Part II     27.6763
# ...          ...      ...                                ...         ...
# 9967        9967    38322  Big Mommas: Like Father, Like Son      3.3429
# 9970        9970   277685                         Unfriended      3.4109
# 9971        9971    10923                   Agent Cody Banks      2.6469
# 9972        9972     9904                           The Wild      4.8729
# 9977        9977     8859              Dude, Where's My Car?      2.8157
#
#       adult original_language  \
# 0     False                en
# ...

# %%
df[df['original_language'] == 'ja']
# Out:
#       Unnamed: 0      id                             title  popularity  adult  \
# 8              8     129                     Spirited Away     32.2851  False
# 16            16  372058                        Your Name.     28.9733  False
# 22            22     346                     Seven Samurai     13.9369  False
# 23            23   12477            Grave of the Fireflies      0.0128  False
# 27            27   14537                          Harakiri      9.1065  False
# ...          ...     ...                               ...         ...    ...
# 8701        8701    1679              Godzilla Raids Again      2.3828  False
# 8801        8801   59429  Paranormal Activity: Tokyo Night      1.6746  False
# 9149        9149  485942                      Batman Ninja      4.1887  False
# 9368        9368    9669                            Ring 2      3.4635  False
# 9413        9413   39106          Dragon Ball Z: Bio-Broly      3.6402  False
#
# ...
